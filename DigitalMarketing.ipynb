# %% [raw]
# 1. Project Goal
#
# Analyze marketing campaign data and generate AI-driven marketing suggestions such as:
#
# Best performing marketing channel
#
# Audience targeting insights
#
# Budget allocation recommendations
#
# Campaign improvement ideas

# %% [raw]
# 2. Example Dataset
#
# Example campaign dataset:
#
# campaign	channel	impressions	clicks	conversions	cost
# Summer Sale	Facebook	10000	800	120	500
# Travel Deals	Google Ads	12000	900	150	700
# Holiday Promo	Instagram	9000	700	100	400

# %% [markdown]
# Install Libraries

# %%
pip install pandas openai matplotlib
# Out:
# Requirement already satisfied: pandas in D:\python\Lib\site-packages (2.3.3)
# Requirement already satisfied: openai in D:\python\Lib\site-packages (2.17.0)
# Requirement already satisfied: matplotlib in D:\python\Lib\site-packages (3.10.8)
# Requirement already satisfied: numpy>=1.26.0 in D:\python\Lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in D:\python\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in D:\python\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in D:\python\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in D:\python\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in D:\python\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in D:\python\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in D:\python\Lib\site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in D:\python\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in D:\python\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in D:\python\Lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in D:\python\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in D:\python\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in D:\python\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in D:\python\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in D:\python\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\python\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in D:\python\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in D:\python\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in D:\python\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in D:\python\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in D:\python\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in D:\python\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in D:\python\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in D:\python\Lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in D:\python\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in D:\python\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in D:\python\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Load Data Using Pandas

# %%
import pandas as pd

data = {
"campaign":["Summer Sale","Travel Deals","Holiday Promo"],
"channel":["Facebook","Google Ads","Instagram"],
"impressions":[10000,12000,9000],
"clicks":[800,900,700],
"conversions":[120,150,100],
"cost":[500,700,400]
}

df = pd.DataFrame(data)

print(df)
# Out:
#         campaign     channel  impressions  clicks  conversions  cost
# 0    Summer Sale    Facebook        10000     800          120   500
# 1   Travel Deals  Google Ads        12000     900          150   700
# 2  Holiday Promo   Instagram         9000     700          100   400

# %% [markdown]
# Click Through Rate (CTR)

# %%
df["CTR"] = df["clicks"] / df["impressions"]

# %% [markdown]
# Conversion Rate

# %%
df["conversion_rate"] = df["conversions"] / df["clicks"]

# %% [markdown]
# Cost Per Conversion

# %%
df["cost_per_conversion"] = df["cost"] / df["conversions"]

# %% [markdown]
# Visualization of Campaign Performance

# %%
import matplotlib.pyplot as plt

df.plot(x="campaign", y="conversions", kind="bar")

plt.title("Campaign Conversions")
plt.xlabel("Campaign")
plt.ylabel("Conversions")

plt.show()

# %% [markdown]
# Generate AI Marketing Suggestions

# %%
from openai import OpenAI

client = OpenAI()

summary = df.to_string()

response = client.responses.create(
    model="gpt-4.1-mini",
    input=f"Analyze this digital marketing campaign data and suggest improvements:\n{summary}"
)

print(response.output_text)
# Out:
# Here's an analysis of the campaign data provided and suggestions for improvement:
#
# ### Data Summary:
#
# | Campaign     | Channel    | Impressions | Clicks | Conversions | Cost | CTR    | Conversion Rate | Cost per Conversion |
# |--------------|------------|-------------|--------|-------------|------|--------|-----------------|---------------------|
# | Summer Sale  | Facebook   | 10,000      | 800    | 120         | 500  | 8.0%   | 15.0%           | $4.17               |
# | Travel Deals | Google Ads | 12,000      | 900    | 150         | 700  | 7.5%   | 16.7%           | $4.67               |
# | Holiday Promo| Instagram  | 9,000       | 700    | 100         | 400  | 7.8%   | 14.3%           | $4.00               |
#
# ---
#
# ### Key Observations:
#
# 1. **Click-Through Rate (CTR)**:
#    - All campaigns have similar CTR (~7.5-8%).
#    - Summer Sale (Facebook) has the highest CTR at 8%.
#
# 2. **Conversion Rate**:
#    - Travel Deals (Google Ads) leads with 16.7%.
#    - Holiday Promo (Instagram) has the lowest at 14.3%.
#
# 3. **Cost Efficiency**:
#    - Holiday Promo has the lowest cost per conversion ($4.00).
#    - Travel Deals is the most expensive at $4.67 per conversion.
#
# 4. **Volume**:
#    - Travel Deals has the highest impressions and conversions.
#    - Holiday Promo has the lowest impressions and conversions but is the most cost-efficient.
#
# ---
#
# ### Recommendations for improvement:
#
# #### 1. **Optimize Google Ads (Travel Deals)**:
# - Despite high conversions, it has the highest cost per conversion.
# - Actions:
#   - Review keywords for relevancy and bid adjustments to reduce wasted spend.
#   - A/B test ad copies to improve CTR and conversion rates.
#   - Use negative keywords to filter irrelevant traffic.
#   - Focus budget on high-performing keywords/ad groups.
#
# #### 2. **Increase Instagram Impressions and Scaling**:
# - Instagram Holiday Promo has good cost efficiency but low impressions.
# - Actions:
#   - Increase budget or bid for Instagram to scale up reach.
#   - Explore influencer collaborations to boost visibility.
#   - Test different content formats (Stories, Reels) to improve CTR and conversions.
#
# #### 3. **Improve Facebook Campaign Conversions**:
# - Summer Sale has strong CTR but lower conversion rate than Google Ads.
# - Actions:
#   - Examine landing page experience for users coming from Facebook.
#   - Implement retargeting campaigns to nurture interested users.
#   - Use personalized ads based on user behavior to improve conversion.
#
# #### 4. **Cross-Channel Retargeting and Attribution**:
# - Implement retargeting strategies across channels for users who clicked but didn't convert.
# - Analyze attribution model to better understand the contribution of each channel.
#
# #### 5. **General Suggestions**:
# - Enhance conversion tracking and attribution accuracy.
# - Periodically review audience segments for each campaign.
# - Use lookalike audiences (Facebook/Instagram) and in-market audiences (Google) for better targeting.
#
# ---
#
# By focusing on improving cost efficiency in Google Ads, scaling the cost-efficient Instagram campaign, and increasing conversions on Facebook, the overall campaign performance should improve.
