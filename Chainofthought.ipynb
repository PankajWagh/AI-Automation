# %%
from openai import OpenAI
from pydantic import BaseModel

client = OpenAI()

class Step(BaseModel):
    explanation: str
    output: str

class MathReasoning(BaseModel):
    steps: list[Step]
    final_answer: str

response = client.responses.parse(
    model="gpt-4o-2024-08-06",
    input=[
        {
            "role": "system",
            "content": "You are a helpful math tutor. Guide the user through the solution step by step.",
        },
        {"role": "user", "content": "how can I solve 8x + 7 = -23"},
    ],
    text_format=MathReasoning,
)

math_reasoning = response.output_parsed
print(math_reasoning)
# Out:
# steps=[Step(explanation='The equation given is 8x + 7 = -23. To find the value of x, we need to isolate it on one side of the equation.', output='8x + 7 = -23'), Step(explanation='We start by eliminating the constant term on the left side. Subtract 7 from both sides to do this.', output='8x + 7 - 7 = -23 - 7'), Step(explanation='Simplifying both sides results in:', output='8x = -30'), Step(explanation='Now, we need to isolate x. Divide both sides of the equation by 8 to solve for x.', output='8x/8 = -30/8'), Step(explanation='Simplify the right side to find the value of x. Dividing -30 by 8 gives us:', output='x = -30/8'), Step(explanation='Further simplify -30/8 by reducing the fraction:', output='x = -15/4'), Step(explanation='Convert the fraction to a decimal to make it easier to understand. Divide -15 by 4 to get:', output='x = -3.75')] final_answer='x = -3.75'
