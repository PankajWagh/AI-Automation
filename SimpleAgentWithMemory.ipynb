# %%
# !pip install openai langchain faiss-cpu tiktoken
# Out:
# Requirement already satisfied: openai in .\myenv\Lib\site-packages (1.109.1)
# Requirement already satisfied: langchain in .\myenv\Lib\site-packages (0.1.17)
# Requirement already satisfied: faiss-cpu in .\myenv\Lib\site-packages (1.13.2)
# Requirement already satisfied: tiktoken in .\myenv\Lib\site-packages (0.12.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\myenv\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in .\myenv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\myenv\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in .\myenv\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in .\myenv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\myenv\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in .\myenv\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in .\myenv\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in .\myenv\Lib\site-packages (from langchain) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\Lib\site-packages (from langchain) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in .\myenv\Lib\site-packages (from langchain) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in .\myenv\Lib\site-packages (from langchain) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in .\myenv\Lib\site-packages (from langchain) (0.1.53)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in .\myenv\Lib\site-packages (from langchain) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in .\myenv\Lib\site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in .\myenv\Lib\site-packages (from langchain) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\myenv\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain) (1.1.0)
# Requirement already satisfied: regex>=2022.1.18 in .\myenv\Lib\site-packages (from tiktoken) (2026.2.28)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain.memory import ConversationBufferMemory
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
llm = ChatOpenAI(model="gpt-4", temperature=0)

# %%
docs = [
    Document(page_content="Python is a programming language."),
    Document(page_content="LangChain helps build LLM-powered apps."),
    Document(page_content="FAISS is a vector database for similarity search.")
]

splitter = RecursiveCharacterTextSplitter(chunk_size=200, chunk_overlap=20)
chunks = splitter.split_documents(docs)

vectorstore = FAISS.from_documents(chunks, embeddings)

# %%
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

rag_chain = ConversationalRetrievalChain.from_llm(
    llm,
    retriever=vectorstore.as_retriever(),
    memory=memory
)

# %%
query1 = "What is LangChain?"
response1 = rag_chain.invoke({"question": query1})
print(response1["answer"])

query2 = "How does it relate to FAISS?"
response2 = rag_chain.invoke({"question": query2})
print(response2["answer"])

query3 = "Remind me what Python is."
response3 = rag_chain.invoke({"question": query3})
print(response3["answer"])
# Out:
# LangChain is a tool that helps build LLM-powered apps. However, the text doesn't provide more specific details about what LangChain is or what LLM-powered apps are.
# The text doesn't provide information on how LangChain relates to FAISS.
# Python is a programming language. It is known for its simplicity and readability, making it a popular choice for beginners and experts alike. It is used in various fields such as web development, data analysis, artificial intelligence, and more.
