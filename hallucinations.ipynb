# %%
from langchain_openai import ChatOpenAI

# GPT-4 for complex reasoning
llm_gpt4 = ChatOpenAI(model="gpt-4")

# GPT-4 Turbo for production workloads
llm_gpt4_turbo = ChatOpenAI(model="gpt-4-turbo")

# GPT-3.5 Turbo for lightweight apps
llm_gpt35 = ChatOpenAI(model="gpt-3.5-turbo")

# GPT-4 for complex reasoning
llm_gpt5 = ChatOpenAI(model="gpt-5")

# Example query
print("llm_gpt5")
response = llm_gpt5.invoke("Wagh Toothpaste")
print(response.content)
print("llm_gpt4")
response = llm_gpt4.invoke("Wagh Toothpaste")
print(response.content)
print("llm_gpt4_turbo")
response = llm_gpt4_turbo.invoke("Wagh Toothpaste")
print(response.content)
print("llm_gpt35")
response = llm_gpt35.invoke("Wagh Toothpaste")
print(response.content)
# Out:
# llm_gpt5
# Could you clarify what you’re looking for about “Wagh Toothpaste”? For example:
# - Product details (ingredients, benefits, fluoride content)
# - Price and availability in your area
# - Reviews or comparisons with other toothpastes
# - Marketing copy/branding help
#
# If you meant “Meswak/Miswak toothpaste” (e.g., Dabur Meswak), let me know and I’ll share verified info. If it’s a specific “Wagh” brand, a link or photo would help me find the exact product.
# llm_gpt4
# There doesn't seem to be a widely recognized brand by the name "Wagh Toothpaste." It's possible you may be referring to a regional, less-known brand or there might be a spelling mistake in the name. Please check and ask again.
# llm_gpt4_turbo
# As of my last update, there isn't specific information about a product called "Wagh Toothpaste." It's possible that it might be a brand not widely recognized or documented in accessible global databases or mainstream markets. If it's a newer or local product, information might be scarce or not yet widely distributed online.
#
# To assist you better, could you provide more details about the product or its context? For instance, where you heard about it, what country or region it's sold in, or any other attributes? This information would help in finding more relevant details or advising on similar products that are well-documented.
# llm_gpt35
# Wagh Toothpaste is a dental care product that is popular in India. It is known for its natural ingredients and refreshing taste. The toothpaste is designed to help prevent cavities, gum disease, and bad breath. Many people who use Wagh Toothpaste report that it leaves their teeth feeling clean and their breath smelling fresh.
