# %%
# !pip uninstall -y langchain langchain-core langchain-openai langchain-community pandas pypdf 
# !pip install langchain==0.1.17
# !pip install langchain-openai==0.0.6
# !pip install langchain-core==0.1.53 
# !pip install langchain-community==0.0.33
# !pip install pandas
# !pip install pypdf
# Out:
# Found existing installation: langchain 0.1.17
# Uninstalling langchain-0.1.17:
#   Successfully uninstalled langchain-0.1.17
# Found existing installation: langchain-core 0.1.53
# Uninstalling langchain-core-0.1.53:
#   Successfully uninstalled langchain-core-0.1.53
# Found existing installation: langchain-openai 0.0.6
# Uninstalling langchain-openai-0.0.6:
#   Successfully uninstalled langchain-openai-0.0.6
# Found existing installation: langchain-community 0.0.38
# Uninstalling langchain-community-0.0.38:
#   Successfully uninstalled langchain-community-0.0.38
# Found existing installation: pandas 2.3.3
# Uninstalling pandas-2.3.3:
#   Successfully uninstalled pandas-2.3.3
# Found existing installation: pypdf 6.9.2
# Uninstalling pypdf-6.9.2:
#   Successfully uninstalled pypdf-6.9.2
# WARNING: Failed to remove contents in a temporary directory 'D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages\~-ndas.libs'.
# You can safely remove it manually.
# WARNING: Failed to remove contents in a temporary directory 'D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages\~-ndas'.
# You can safely remove it manually.
# Collecting langchain==0.1.17
#   Using cached langchain-0.1.17-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain==0.1.17) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\Lib\site-packages (from langchain==0.1.17) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain==0.1.17) (1.33)
# Collecting langchain-community<0.1,>=0.0.36 (from langchain==0.1.17)
#   Using cached langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2.0,>=0.1.48 (from langchain==0.1.17)
#   Using cached langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain==0.1.17) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain==0.1.17) (23.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (1.0.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (4.12.1)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\myenv\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.1.0)
# Using cached langchain-0.1.17-py3-none-any.whl (867 kB)
# Using cached langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
# Using cached langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Installing collected packages: langchain-core, langchain-community, langchain
#
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ---------------------------------------- 0/3 [langchain-core]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    ------------- -------------------------- 1/3 [langchain-community]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    -------------------------- ------------- 2/3 [langchain]
#    ---------------------------------------- 3/3 [langchain]
#
# Successfully installed langchain-0.1.17 langchain-community-0.0.38 langchain-core-0.1.53
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000214D596DD90>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network')': /simple/langchain/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000214D5AAFC20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000214D5AA3740>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000214D5AA1460>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x00000214D5AA1580>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/langchain/
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.3 requires langchain-core<2.0.0,>=1.2.19, but you have langchain-core 0.1.53 which is incompatible.
# langchain-classic 1.0.3 requires langchain-text-splitters<2.0.0,>=1.1.1, but you have langchain-text-splitters 0.0.2 which is incompatible.
# langchain-mcp 0.2.1 requires langchain-core~=0.3.37, but you have langchain-core 0.1.53 which is incompatible.
# langgraph-checkpoint 4.0.1 requires langchain-core>=0.2.38, but you have langchain-core 0.1.53 which is incompatible.
# langgraph-prebuilt 1.0.8 requires langchain-core>=1.0.0, but you have langchain-core 0.1.53 which is incompatible.
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Collecting langchain-openai==0.0.6
#   Using cached langchain_openai-0.0.6-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: langchain-core<0.2,>=0.1.16 in .\myenv\Lib\site-packages (from langchain-openai==0.0.6) (0.1.53)
# Requirement already satisfied: numpy<2,>=1 in .\myenv\Lib\site-packages (from langchain-openai==0.0.6) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in .\myenv\Lib\site-packages (from langchain-openai==0.0.6) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.5.2 in .\myenv\Lib\site-packages (from langchain-openai==0.0.6) (0.12.0)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (0.1.147)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (2.12.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (3.11.7)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (1.0.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (4.12.1)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (0.13.0)
# Requirement already satisfied: sniffio in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in .\myenv\Lib\site-packages (from openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core<0.2,>=0.1.16->langchain-openai==0.0.6) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in .\myenv\Lib\site-packages (from tiktoken<1,>=0.5.2->langchain-openai==0.0.6) (2026.2.28)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from tqdm>4->openai<2.0.0,>=1.10.0->langchain-openai==0.0.6) (0.4.6)
# Using cached langchain_openai-0.0.6-py3-none-any.whl (29 kB)
# Installing collected packages: langchain-openai
# Successfully installed langchain-openai-0.0.6
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Requirement already satisfied: langchain-core==0.1.53 in .\myenv\Lib\site-packages (0.1.53)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (6.0.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (0.1.147)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (2.12.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain-core==0.1.53) (8.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.1.53) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (3.11.7)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (2.32.5)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (1.0.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (4.12.1)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core==0.1.53) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core==0.1.53) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core==0.1.53) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core==0.1.53) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.0->langchain-core==0.1.53) (2.6.3)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Collecting langchain-community==0.0.33
#   Using cached langchain_community-0.0.33-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (0.6.7)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.43 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (0.1.53)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain-community==0.0.33) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.0.33) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.33) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.33) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (2.12.5)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (1.0.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (4.12.1)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community==0.0.33) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain-core<0.2.0,>=0.1.43->langchain-community==0.0.33) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain-community==0.0.33) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain-community==0.0.33) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\myenv\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.0.33) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.0.33) (1.1.0)
# Using cached langchain_community-0.0.33-py3-none-any.whl (1.9 MB)
# Installing collected packages: langchain-community
#   Attempting uninstall: langchain-community
#     Found existing installation: langchain-community 0.0.38
#     Uninstalling langchain-community-0.0.38:
#       Successfully uninstalled langchain-community-0.0.38
# Successfully installed langchain-community-0.0.33
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.1.17 requires langchain-community<0.1,>=0.0.36, but you have langchain-community 0.0.33 which is incompatible.
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Collecting pandas
#   Using cached pandas-3.0.1-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in .\myenv\Lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\myenv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in .\myenv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in .\myenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-3.0.1-cp312-cp312-win_amd64.whl (9.7 MB)
# Installing collected packages: pandas
# Successfully installed pandas-3.0.1
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.55.0 requires pandas<3,>=1.4.0, but you have pandas 3.0.1 which is incompatible.
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Collecting pypdf
#   Using cached pypdf-6.9.2-py3-none-any.whl.metadata (7.1 kB)
# Using cached pypdf-6.9.2-py3-none-any.whl (333 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.9.2
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain.chains import LLMChain
import pandas as pd
from openai import OpenAI
from pypdf import PdfReader

# %%
# Initialize LLM
llm = ChatOpenAI(model="gpt-4-turbo")

# %%
# Define a prompt template for sentiment analysis
prompt = PromptTemplate(
    input_variables=["text"],
    template="Analyze the sentiment of the following text. "
             "Classify as Positive, Negative, or Neutral, and explain briefly:\n\n{text}"
)

# %%
client = OpenAI()

# %%
# Build chain
sentiment_chain = prompt | llm

# %%
# Example: Document-level
# creating a pdf reader object
reader = PdfReader('comment.pdf')

# printing number of pages in pdf file
print(len(reader.pages))

# getting a specific page from the pdf file
page = reader.pages[0]

# extracting text from page
document = page.extract_text()
print(document)

result_doc = sentiment_chain.invoke(document)
print("Document Sentiment:", result_doc)
# Out:
# 1
# Excellent performance for the price with good battery back up. And the icing on the cake is the Camera.... Just top notch and great low light
# photography. The only concern is there is no charger we have to purchase separately. Nice under deal price 13k but performance is low compared to
# inbuilt features camera is not expected level more over battery is loosing it's percentage by every five mints automatic with use then how can play
# games not even statss for using the YouTube for 1 hour total battery drop
# 3/21/26, 12:10 AM test.html
# file:///C:/Users/panka/OneDrive/Desktop/test.html 1/1
# Document Sentiment: content="The sentiment of the provided text is **Negative**.\n\n**Explanation:**\nThe text begins with positive remarks about the product's performance, battery life, and camera quality, which might suggest a positive sentiment. However, as the review progresses, it highlights significant drawbacks, including the absence of a charger, the low performance relative to expectations from the inbuilt features, and the rapid depletion of the battery. The concerns about battery life are particularly emphasized with specific details about its fast draining, which significantly impacts usability for games or watching videos. These negative aspects, particularly the functional limitations and additional costs, outweigh the initial positive comments, leading to an overall negative sentiment." response_metadata={'token_usage': {'completion_tokens': 131, 'prompt_tokens': 169, 'total_tokens': 300, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_96a644d644', 'finish_reason': 'stop', 'logprobs': None} id='run-95b9c509-a027-4fec-8217-fec54c636161-0'

# %%
# Example: Document-level
document = """The new HR policy is very supportive of employees, 
but some feel the leave restrictions are too strict."""
result_doc = sentiment_chain.invoke(document)
print("Document Sentiment:", result_doc)
# Out:
# Document Sentiment: content='Sentiment: Mixed (or Neutral leaning)\n\nExplanation: The text presents both a positive and a negative aspect of the new HR policy. The initial part of the text highlights that the policy is "very supportive of employees," which suggests a positive sentiment as it implies benefits or improvements for employees. However, the latter part of the text mentions that "some feel the leave restrictions are too strict," which introduces a negative sentiment as it indicates dissatisfaction or limitations imposed on employees. The combination of these opposing sentiments leads to a mixed or neutral overall sentiment, as the positive and negative aspects counterbalance each other.' response_metadata={'token_usage': {'completion_tokens': 119, 'prompt_tokens': 51, 'total_tokens': 170, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_24fa6ededa', 'finish_reason': 'stop', 'logprobs': None} id='run-f33c8257-270b-4339-a359-49fc08c9d3d2-0'

# %%
# Example: Paragraph-level
paragraph = "Excellent smartwatch with great features at a very reasonable price! The display is bright, clear, and responsive, making it easy to use even in sunlight. The design is sleek and comfortable, perfect for all-day wear. Battery life is impressive—I can easily use it for several days on a single charge. The fitness tracking features like heart rate monitoring, step count, and sleep tracking are accurate and very helpful for daily health monitoring. It also connects smoothly with the phone, and notifications come instantly without any lag. Overall, a perfect combination of style, performance, and value for money. Highly recommended for anyone looking for a reliable smartwatch!"
result_para = sentiment_chain.invoke(paragraph)
print("\n Paragraph Sentiment:", result_para)

paragraph1 = "Your first response times have gone up in the last few weeks, so customers are waiting longer than normal to hear back about their issues. Are there any bugs or products that you’re having trouble with? Let’s go over some of your tickets and talk about what aspects might be slowing down your responses."
result_para1 = sentiment_chain.invoke(paragraph1)
print("\n Paragraph Sentiment:", result_para1)


paragraph2 = "Battery draining very fast even without doing anything. Connection & synchronisation problem. Very much lagging. Much better products available at less than its half price."
result_para2 = sentiment_chain.invoke(paragraph2)
print("\n Paragraph Sentiment:", result_para2)
# Out:
#  Paragraph Sentiment: content='Sentiment: Positive\n\nExplanation:\nThe text provides a highly favorable review of the smartwatch, emphasizing its excellent features, usability, and value for money. Positive adjectives such as "excellent," "great," "bright," "clear," "responsive," "sleek," "comfortable," "impressive," and "accurate" contribute to a positive sentiment. The text concludes with a strong recommendation, further affirming the positive sentiment. The overall tone is enthusiastic and satisfied, indicating that the user\'s experience with the product is highly positive.' response_metadata={'token_usage': {'completion_tokens': 112, 'prompt_tokens': 158, 'total_tokens': 270, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_5ec839fa0f', 'finish_reason': 'stop', 'logprobs': None} id='run-3c274a48-8e78-4ef8-a523-b16c98105f73-0'
#
#  Paragraph Sentiment: content='The sentiment of the text is Neutral.\n\nExplanation:\nThe text is primarily focused on addressing an issue regarding increased first response times to customers. The tone is constructive and solution-oriented, neither expressing dissatisfaction nor praise. It seeks to understand the root causes (asking about bugs or product issues) and suggests reviewing tickets to identify any slowdowns in response times. The intent is to improve the service, indicating a neutral stance aimed at problem-solving rather than conveying any strong positive or negative emotions.' response_metadata={'token_usage': {'completion_tokens': 95, 'prompt_tokens': 90, 'total_tokens': 185, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_6c44252b36', 'finish_reason': 'stop', 'logprobs': None} id='run-bbe678e1-1be4-420d-a8a7-532aad5cb4f5-0'
#
#  Paragraph Sentiment: content='The sentiment of the provided text is Negative. The text expresses dissatisfaction with a product, mentioning specific issues such as rapid battery drain, connection and synchronization problems, and performance lag. Additionally, the comparison to other products that are cheaper and presumably better underscores the negative sentiment towards the product being discussed.' response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 61, 'total_tokens': 119, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_25c5cadb08', 'finish_reason': 'stop', 'logprobs': None} id='run-c7fd6bc8-fb6f-467a-bd91-a8a191ca69ec-0'

# %%
data = {
    "review": [
        "The product quality is amazing!",
        "Delivery was very slow",
        "Customer support helped me quickly",
        "Very bad experience",
        "Excellent service and fast shipping",
        "The packaging was damaged",
        "Great product value"
    ]
}

df = pd.DataFrame(data)

# %%
def get_sentiment(review):
    result_para_sentiment = sentiment_chain.invoke(review)
    print("\n sentence Sentiment:", result_para_sentiment)

# %%
df["review"].apply(get_sentiment)
# Out:
#  sentence Sentiment: content='The sentiment of the text "The product quality is amazing!" is Positive. The exclamation mark emphasizes strong positive feelings, and the word "amazing" is commonly used to express high satisfaction and approval, indicating a very favorable view of the product\'s quality.' response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 36, 'total_tokens': 88, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_5ec839fa0f', 'finish_reason': 'stop', 'logprobs': None} id='run-28002558-25be-43b3-bd79-be0589875666-0'
#
#  sentence Sentiment: content='The sentiment of the text "Delivery was very slow" is Negative. This is because the phrase "very slow" implies a dissatisfaction with the speed of the delivery, suggesting that it did not meet the expected or desired standards.' response_metadata={'token_usage': {'completion_tokens': 45, 'prompt_tokens': 34, 'total_tokens': 79, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_24fa6ededa', 'finish_reason': 'stop', 'logprobs': None} id='run-e769e02c-ea2d-48d4-be76-5b848349d1ea-0'
#
#  sentence Sentiment: content='The sentiment of the text "Customer support helped me quickly" is Positive. This is because the text expresses satisfaction with the speed of assistance provided by customer support, implying a good customer service experience. The word "quickly" is key here, indicating that the service met or exceeded the customer\'s expectations in terms of response time.' response_metadata={'token_usage': {'completion_tokens': 66, 'prompt_tokens': 35, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_2fb3c6905f', 'finish_reason': 'stop', 'logprobs': None} id='run-b1cd12b4-2d52-48c2-b9ff-69106cddd044-0'
#
#  sentence Sentiment: content='The sentiment of the text "Very bad experience" is Negative. This conclusion is based on the use of the words "very bad," which strongly express a negative opinion or feeling about the experience mentioned. The term "bad" directly conveys a sense of dissatisfaction or unpleasantness, intensified by the word "very," indicating a high level of negativity.' response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 33, 'total_tokens': 103, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_7e0dfb719c', 'finish_reason': 'stop', 'logprobs': None} id='run-4f8a1ef7-6f89-4581-a68c-77d2dfbb0155-0'
#
#  sentence Sentiment: content='The sentiment of the text "Excellent service and fast shipping" is Positive. The use of the word "excellent" to describe the service indicates a high level of satisfaction, and "fast shipping" suggests that the speed of delivery was also satisfactory and likely exceeded expectations. Both elements contribute to a positive assessment of the experience.' response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 35, 'total_tokens': 100, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_96a644d644', 'finish_reason': 'stop', 'logprobs': None} id='run-483fe5b5-3e86-41e7-8a1b-215f3acb9e73-0'
#
#  sentence Sentiment: content='The sentiment of the text "The packaging was damaged" is Negative. This statement indicates a problem or dissatisfaction with the state of the packaging, which is generally regarded as an undesirable outcome. The use of the word "damaged" specifically conveys a negative experience related to the product\'s condition upon receipt.' response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 34, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_24fa6ededa', 'finish_reason': 'stop', 'logprobs': None} id='run-44157aa5-536a-4c67-94a9-7018bbbf251e-0'
#
#  sentence Sentiment: content='The sentiment of the text "Great product value" is Positive.\n\nExplanation: The word "great" is a positive descriptor indicating high quality or satisfaction, and "product value" suggests that the product provides good worth for its price or utility. The combination of these terms conveys a favorable opinion about the product.' response_metadata={'token_usage': {'completion_tokens': 62, 'prompt_tokens': 33, 'total_tokens': 95, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4-turbo', 'system_fingerprint': 'fp_25c5cadb08', 'finish_reason': 'stop', 'logprobs': None} id='run-ae577a65-c047-4bfb-8c35-8337e6f18604-0'
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# 5    None
# 6    None
# Name: review, dtype: object
