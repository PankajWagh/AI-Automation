# %%
# !pip install streamlit python-docx
# !pip install langchain==0.1.17
# !pip install --upgrade openai
# !pip install playsound==1.2.2
# Out:
# Requirement already satisfied: streamlit in .\myenv\Lib\site-packages (1.55.0)
# Requirement already satisfied: python-docx in .\myenv\Lib\site-packages (1.2.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in .\myenv\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in .\myenv\Lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in .\myenv\Lib\site-packages (from streamlit) (7.0.5)
# Requirement already satisfied: click<9,>=7.0 in .\myenv\Lib\site-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in .\myenv\Lib\site-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in .\myenv\Lib\site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging>=20 in .\myenv\Lib\site-packages (from streamlit) (23.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in .\myenv\Lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in .\myenv\Lib\site-packages (from streamlit) (12.1.1)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in .\myenv\Lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in .\myenv\Lib\site-packages (from streamlit) (6.33.6)
# Requirement already satisfied: pyarrow>=7.0 in .\myenv\Lib\site-packages (from streamlit) (23.0.1)
# Requirement already satisfied: requests<3,>=2.27 in .\myenv\Lib\site-packages (from streamlit) (2.32.5)
# Requirement already satisfied: tenacity<10,>=8.1.0 in .\myenv\Lib\site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in .\myenv\Lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in .\myenv\Lib\site-packages (from streamlit) (6.5.5)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in .\myenv\Lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in .\myenv\Lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in .\myenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in .\myenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.27.1 in .\myenv\Lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.18.0)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in .\myenv\Lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in .\myenv\Lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\myenv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\myenv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in .\myenv\Lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in .\myenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in .\myenv\Lib\site-packages (from requests<3,>=2.27->streamlit) (2026.2.25)
# Requirement already satisfied: lxml>=3.1.0 in .\myenv\Lib\site-packages (from python-docx) (6.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in .\myenv\Lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in .\myenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\myenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\myenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\myenv\Lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in .\myenv\Lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Requirement already satisfied: langchain==0.1.17 in .\myenv\Lib\site-packages (0.1.17)
# Requirement already satisfied: PyYAML>=5.3 in .\myenv\Lib\site-packages (from langchain==0.1.17) (6.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.0.48)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in .\myenv\Lib\site-packages (from langchain==0.1.17) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\myenv\Lib\site-packages (from langchain==0.1.17) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.36 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.48 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.1.53)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.0.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in .\myenv\Lib\site-packages (from langchain==0.1.17) (0.1.147)
# Requirement already satisfied: numpy<2,>=1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.12.5)
# Requirement already satisfied: requests<3,>=2 in .\myenv\Lib\site-packages (from langchain==0.1.17) (2.32.5)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in .\myenv\Lib\site-packages (from langchain==0.1.17) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\myenv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.17) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in .\myenv\Lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\myenv\Lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.17) (3.0.0)
# Requirement already satisfied: packaging<24.0,>=23.2 in .\myenv\Lib\site-packages (from langchain-core<0.2.0,>=0.1.48->langchain==0.1.17) (23.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.11.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\myenv\Lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (1.0.0)
# Requirement already satisfied: anyio in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (4.12.1)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (1.0.9)
# Requirement already satisfied: idna in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (3.11)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain==0.1.17) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1->langchain==0.1.17) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain==0.1.17) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\myenv\Lib\site-packages (from requests<3,>=2->langchain==0.1.17) (2.6.3)
# Requirement already satisfied: greenlet>=1 in .\myenv\Lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.17) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in .\myenv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.17) (1.1.0)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Requirement already satisfied: openai in .\myenv\Lib\site-packages (0.28.0)
# Collecting openai
#   Using cached openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\myenv\Lib\site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in .\myenv\Lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\myenv\Lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in .\myenv\Lib\site-packages (from openai) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in .\myenv\Lib\site-packages (from openai) (2.12.5)
# Requirement already satisfied: sniffio in .\myenv\Lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in .\myenv\Lib\site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in .\myenv\Lib\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in .\myenv\Lib\site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in .\myenv\Lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in .\myenv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\myenv\Lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: colorama in .\myenv\Lib\site-packages (from tqdm>4->openai) (0.4.6)
# Using cached openai-2.32.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.28.0
#     Uninstalling openai-0.28.0:
#       Successfully uninstalled openai-0.28.0
# Successfully installed openai-2.32.0
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.0.6 requires openai<2.0.0,>=1.10.0, but you have openai 2.32.0 which is incompatible.
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# Requirement already satisfied: playsound==1.2.2 in .\myenv\Lib\site-packages (1.2.2)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~angchain-community (D:\Ethans\Python\AI-Automation\myenv\Lib\site-packages)

# %%
import os
from langchain_openai import ChatOpenAI
import openai
from playsound import playsound

# Path to your audio file (mp3, wav, m4a, etc.)
audio_file_path = "Monologue.ogg"
#playsound(audio_file_path)

# Open the file in binary mode
with open(audio_file_path, "rb") as audio_file:
    transcript = openai.audio.transcriptions.create(
        model="whisper-1",  # or "whisper-1"
        file=audio_file
    )

print("Transcript:")
print(transcript.text)
print(audio_file_path);
file_path = os.path.join(os.getcwd(), audio_file_path)
#playsound(file_path)
# Out:
# Transcript:
# LeGel. Glad to see things are going well and business is starting to pick up. Andrea told me about your outstanding numbers on Tuesday. Keep up the good work. Now to other business. I am going to suggest a payment schedule for the outstanding monies that is due. One, can you pay the balance of the license agreement as soon as possible? Two, I suggest we set up or you suggest what you can pay on the back royalties. What do you feel comfortable with paying every two weeks? Every month? I would like to keep, I would like to catch up and maintain current royalties. So if we can start current royalties and maintain them every two weeks as all stores are required to do, I would appreciate it. Let me know if this works for you. Thanks.
# Monologue.ogg

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

prompt = f"""
You are an AI Meeting Notes Generator.
Summarize the following transcript into:
- Meeting Summary
- Key Decisions
    - Reminders
    - Risks 
    - Pending Approvals
- Action Items (with assignees if mentioned)
- Team Members 
Transcript:
{transcript.text}
"""
print("Meeting Note:")
response = llm.invoke(prompt)
print(response.content)
# Out:
# Meeting Note:
# ### Meeting Summary
# The meeting focused on discussing the financial status and payment schedule regarding outstanding payments, specifically the balance of the license agreement and back royalties. The speaker expressed satisfaction with the business's progress and emphasized the importance of maintaining current royalty payments.
#
# ### Key Decisions
# - **Reminders**:
#   - The need to pay the balance of the license agreement as soon as possible.
#   - Establish a payment schedule for back royalties.
#
# - **Risks**:
#   - Potential delays in payments could affect the maintenance of current royalties.
#
# - **Pending Approvals**:
#   - Awaiting confirmation on the proposed payment schedule from the other party.
#
# ### Action Items
# - **Payment of License Agreement Balance**:
#   - **Assignee**: Not specified, but implied to be the recipient of the message.
#
# - **Establish Payment Schedule for Back Royalties**:
#   - **Assignee**: Not specified, but the recipient is expected to suggest a comfortable payment frequency (every two weeks or monthly).
#
# ### Team Members
# - LeGel (Speaker)
# - Andrea (mentioned in context of business performance)
# - Recipient of the message (not named)

# %%
translation = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a translator."},
        {"role": "user", "content": f"Translate this into Hindi:\n{transcript.text}"}
    ]
)

print(translation.choices[0].message.content)
# Out:
# लेगेल। यह जानकर खुशी हुई कि सब कुछ ठीक चल रहा है और व्यापार में सुधार आने लगा है। एंड्रिया ने मंगलवार को आपके शानदार आंकड़ों के बारे में बताया। अच्छा काम करते रहें। अब अन्य मामलों की बात करें। मैं बकाया राशि के लिए एक भुगतान कार्यक्रम का सुझाव देने जा रहा हूँ। पहला, क्या आप लाइसेंस अनुबंध की राशि का बाकी हिस्सा जल्द से जल्द चुका सकते हैं? दूसरा, मैं सुझाव देता हूँ कि हम पीछे के रॉयल्टी पर आपके द्वारा भुगतान करने की क्षमता के अनुसार व्यवस्था करें। आप हर दो हफ्ते में भुगतान करने में कितने सहज हैं? हर महीने? मैं चाहता हूँ कि हम वर्तमान रॉयल्टी को बनाए रखें और उन्हें हर दो हफ्ते में बनाए रखें, जैसा कि सभी स्टोर के लिए आवश्यक है। अगर हम वर्तमान रॉयल्टी को शुरू कर सकते हैं और उन्हें हर दो हफ्ते में बनाए रख सकते हैं, तो मुझे इसकी सराहना होगी। मुझे बताएं कि क्या यह आपके लिए काम करता है। धन्यवाद।

# %%
from pathlib import Path
import os
speech_file_path = Path("hindi_output.mp3")

response = openai.audio.speech.create(
    model="gpt-4o-mini-tts",   # TTS model
    voice="alloy",             # choose a voice
    input=translation.choices[0].message.content           # Hindi text from translation
)

# Save audio file
with open(speech_file_path, "wb") as f:
    f.write(response.read())
print(speech_file_path);
file_path = os.path.join(os.getcwd(), speech_file_path)
playsound(file_path)
# Out:
# hindi_output.mp3

# %%
translation = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "system", "content": "You are a translator."},
        {"role": "user", "content": f"Translate this into Marathi:\n{transcript.text}"}
    ]
)

print(translation.choices[0].message.content)
# Out:
# लेगेल. तुम्ही चांगले चालले असल्याचे आणि व्यवसाय पुन्हा सुरळीत होत असल्याचे पाहून आनंद झाला. अँड्रिया ने मंगळवारी तुमच्या उत्कृष्ट संख्यांचे मला सांगितले. चांगले काम चालू ठेवा. आता इतर व्यवसायाकडे वळूया. मी बाकीची रक्कम भरण्यासाठी एक पेमेंट वेळापत्रक सुचवणार आहे. एक, लायसन्स कराराची शिल्लक रक्कम शक्य तितक्या लवकर भरू शकता का? दोन, मी सुचवतो की आपण मागील रॉयल्टीवर काय भरू शकता ते ठरवूया किंवा आपण सुचवू शकता. तुम्हाला प्रत्येक दोन आठवड्यात ते किती सोयीचे आहेत? प्रत्येक महिन्यात? मला चालू रॉयल्टी ठेवायचे आहे आणि त्यांचा दर्जा राखायचा आहे. त्यामुळे जर आपण चालू रॉयल्टी सुरू करू शकलो आणि प्रत्येक दोन आठवड्यांनंतर ती राखू शकलो, तर मला चांगले वाटेल. हे तुमच्यासाठी योग्य आहे का ते मला सांगा. धन्यवाद.

# %%
from pathlib import Path

speech_file_path = Path("marathi_output.mp3")

response = openai.audio.speech.create(
    model="gpt-4o-mini-tts",   # TTS model
    voice="alloy",             # choose a voice
    input=translation.choices[0].message.content           # Hindi text from translation
)

# Save audio file
with open(speech_file_path, "wb") as f:
    f.write(response.read())
print(speech_file_path);
file_path = os.path.join(os.getcwd(), speech_file_path)
playsound(file_path)
# Out:
# marathi_output.mp3

# %%
def sentiment_analysis(transcription):
    response = openai.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "As an AI with expertise in language and emotion analysis, your task is to analyze the sentiment of the following text. Please consider the overall tone of the discussion, the emotion conveyed by the language used, and the context in which words and phrases are used. Indicate whether the sentiment is generally positive, negative, or neutral, and provide brief explanations for your analysis where possible."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
def abstract_summary_extraction(transcription):
    response = openai.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a highly skilled AI trained in language comprehension and summarization. I would like you to read the following text and summarize it into a concise abstract paragraph. Aim to retain the most important points, providing a coherent and readable summary that could help a person understand the main points of the discussion without needing to read the entire text. Please avoid unnecessary details or tangential points."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
def key_points_extraction(transcription):
    response = openai.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are a proficient AI with a specialty in distilling information into key points. Based on the following text, identify and list the main points that were discussed or brought up. These should be the most important ideas, findings, or topics that are crucial to the essence of the discussion. Your goal is to provide a list that someone could read to quickly understand what was talked about."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
def action_item_extraction(transcription):
    response = openai.chat.completions.create(
        model="gpt-4",
        temperature=0,
        messages=[
            {
                "role": "system",
                "content": "You are an AI expert in analyzing conversations and extracting action items. Please review the text and identify any tasks, assignments, or actions that were agreed upon or mentioned as needing to be done. These could be tasks assigned to specific individuals, or general actions that the group has decided to take. Please list these action items clearly and concisely."
            },
            {
                "role": "user",
                "content": transcription
            }
        ]
    )
    return response.choices[0].message.content

# %%
def meeting_minutes(transcription):
    abstract_summary = abstract_summary_extraction(transcription)
    key_points = key_points_extraction(transcription)
    action_items = action_item_extraction(transcription)
    sentiment = sentiment_analysis(transcription)
    return {
        'abstract_summary': abstract_summary,
        'key_points': key_points,
        'action_items': action_items,
        'sentiment': sentiment
    }

# %%
from docx import Document
def save_as_docx(minutes, filename):
    doc = Document()
    for key, value in minutes.items():
        # Replace underscores with spaces and capitalize each word for the heading
        heading = ' '.join(word.capitalize() for word in key.split('_'))
        doc.add_heading(heading, level=1)
        doc.add_paragraph(value)
        # Add a line break between sections
        doc.add_paragraph()
    doc.save(filename)

# %%
print(sentiment_analysis(transcript.text))
minutes = meeting_minutes(transcript.text)
save_as_docx(minutes, 'meeting_minutes.docx')
# Out:
# The sentiment of the text is generally positive. The author starts by expressing satisfaction with LeGel's performance and business growth, which sets a positive tone. The author also acknowledges LeGel's outstanding numbers, further reinforcing the positive sentiment. The discussion about payment schedule and outstanding monies is neutral in sentiment, as it is a business matter and does not convey any particular emotion. The author's tone remains polite and professional throughout, and they express appreciation at the end, which adds to the overall positive sentiment.
