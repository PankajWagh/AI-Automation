# %%
from openai import OpenAI
import networkx as nx

# Step 1: Build a graph
G = nx.Graph()
G.add_edge("Employee", "Policy", relation="complies_with")

# Step 2: Query graph
context = "Employee complies with Policy"

# Step 3: Send to OpenAI
client = OpenAI()
response = client.chat.completions.create(
    model="gpt-4",
    messages=[{"role":"system","content":"Use context from KG"},
              {"role":"user","content":f"Explain: {context}"}]
)
print(response.choices[0].message.content)
# Out:
# When an employee complies with a policy, it means the employee is following and adhering to the rules, guidelines, and standards that are defined by their employer or organization. Policies can include a broad range of parameters, on topics like behavior, performance, dress code, attendance, use of company property, etc. As these policies are typically created to maintain a safe, organized, and fair workplace, compliance signifies that an employee is acting in accordance with these expectations. Non-compliance can result in consequences like disciplinary actions, termination, or legal actions, depending on the policy and infringement.
